# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %%
DATA_DIR = 'D:\AIML PROJ\MASK_RCNN\MASK_RCNN'

# Directory to save logs and trained model
ROOT_DIR = 'checkpoint'

# %%
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_2_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_2_test_images')

# %% [markdown]
# ### Download COCO pre-trained weights

# %%
#downloaded the pre=trained mask_rcnnn_coco weight in this link https://github.com/matterport/Mask_RCNN/releases/download/v2.0/mask_rcnn_coco.h5
COCO_WEIGHTS_PATH =os.path.join(DATA_DIR, 'coco_weight', 'mask_rcnn_coco.h5')

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps_1(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))
    
def get_dicom_fps(dicom_dir):
    a=[]
    os.chdir(r"D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images") 
    folder_path = os.getcwd()
    for pid in df['patientId']:
        #print(pid)
        k=os.path.join(folder_path,pid)
        dicom_fps = k+'.dcm'
        print(dicom_fps)
        a.append(dicom_fps)
        my_finallist = [i for j, i in enumerate(a) if i not in a[:j]] 
    return my_finallist
def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8
    
    BACKBONE = 'resnet101'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    RPN_ANCHOR_SCALES = (64, 128,192)
    RPN_NMS_THRESHOLD  = 0.9
    TRAIN_ROIS_PER_IMAGE = 16
    MAX_GT_INSTANCES = 3
    DETECTION_MAX_INSTANCES = 3 
    DETECTION_MIN_CONFIDENCE = 0.7
    DETECTION_NMS_THRESHOLD = 0.3
    STEPS_PER_EPOCH = 500 
    TRAIN_BN =True 

config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               3
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (64, 128, 192)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.9
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                500
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       True
# TRAIN_ROIS_PER_IMAGE           16
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
os.chdir(r"D:\AIML PROJ\MASK_RCNN\MASK_RCNN") 
cwd = os.getcwd()

# %%
# training dataset
# training dataset
df = pd.read_csv('stage_2_train_labels.csv')
df.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
df.dropna(inplace= True)
df.head(10)
# Out:
#                                patientId      x      y  width  height  Target
# 4   00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# 5   00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0       1
# 8   00704310-78a8-4b38-8475-49f4573b2dbb  323.0  577.0  160.0   104.0       1
# 9   00704310-78a8-4b38-8475-49f4573b2dbb  695.0  575.0  162.0   137.0       1
# 14  00aecb01-a116-45a2-956c-08d2fa55433f  288.0  322.0   94.0   135.0       1
# 15  00aecb01-a116-45a2-956c-08d2fa55433f  547.0  299.0  119.0   165.0       1
# 16  00c0b293-48e7-4e16-ac76-9269ba535a62  306.0  544.0  168.0   244.0       1
# 17  00c0b293-48e7-4e16-ac76-9269ba535a62  650.0  511.0  206.0   284.0       1
# 19  00f08de1-517e-4652-a04f-d1dc9ee48593  181.0  184.0  206.0   506.0       1
# 20  00f08de1-517e-4652-a04f-d1dc9ee48593  571.0  275.0  230.0   476.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=df)
# Out:
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00436515-870c-4b36-a041-de91049b9ab4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00436515-870c-4b36-a041-de91049b9ab4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00704310-78a8-4b38-8475-49f4573b2dbb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00704310-78a8-4b38-8475-49f4573b2dbb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00aecb01-a116-45a2-956c-08d2fa55433f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00aecb01-a116-45a2-956c-08d2fa55433f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00c0b293-48e7-4e16-ac76-9269ba535a62.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00c0b293-48e7-4e16-ac76-9269ba535a62.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00f08de1-517e-4652-a04f-d1dc9ee48593.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\00f08de1-517e-4652-a04f-d1dc9ee48593.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0100515c-5204-4f31-98e0-f35e4b00004a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\010ccb9f-6d46-4380-af11-84f87397a1b8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\010ccb9f-6d46-4380-af11-84f87397a1b8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\012a5620-d082-4bb8-9b3b-e72d8938000c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\012a5620-d082-4bb8-9b3b-e72d8938000c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0174c4bb-28f5-41e3-a13f-a396badc18bd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0174c4bb-28f5-41e3-a13f-a396badc18bd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\019d950b-dd38-4cf3-a686-527a75728be6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\019d950b-dd38-4cf3-a686-527a75728be6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01a6eaa6-222f-4ea8-9874-bbd89dc1a1ce.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01a6eaa6-222f-4ea8-9874-bbd89dc1a1ce.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01a7353d-25bb-4ff8-916b-f50dd541dccf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01a7353d-25bb-4ff8-916b-f50dd541dccf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01adfd2f-7bc7-4cef-ab68-a0992752b620.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01b9e362-4950-40f5-88fa-7557ac2a45bb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01b9e362-4950-40f5-88fa-7557ac2a45bb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01be392f-a46d-4aef-a57e-9cd1a80dd47e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01be392f-a46d-4aef-a57e-9cd1a80dd47e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01cad8d0-45cd-4603-b099-94055d322310.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01cad8d0-45cd-4603-b099-94055d322310.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01cd2ba5-2baf-44b2-bf15-ee57e1ea4599.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01d4fa0f-97a0-4522-b0d8-134400db2a3e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01d4fa0f-97a0-4522-b0d8-134400db2a3e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01dc817c-3cfa-49fe-8662-518edc30652a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01f3abc2-33c7-4ea2-a599-dc49b76fcfae.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01f3abc2-33c7-4ea2-a599-dc49b76fcfae.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01fa0f5e-00c3-41cb-b5c7-10600c8633ae.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01fa0f5e-00c3-41cb-b5c7-10600c8633ae.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01fdfd88-7607-48b9-ba05-a36e8b6fd19b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\01fdfd88-7607-48b9-ba05-a36e8b6fd19b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02002619-3dea-4038-8d4d-458db30ed8de.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02002619-3dea-4038-8d4d-458db30ed8de.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\020380f8-5c5a-4ded-bdf3-9ce3036945b4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\020380f8-5c5a-4ded-bdf3-9ce3036945b4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02099738-7465-4786-b71c-de8cdac477c3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02099738-7465-4786-b71c-de8cdac477c3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\020a16e3-baf9-4cf0-859c-c79b5253d717.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\020a16e3-baf9-4cf0-859c-c79b5253d717.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02285fa4-35b7-4af6-b88f-3cac45a7f5c8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0294b4aa-5614-4b33-80a4-2c31b639e5b3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0294b4aa-5614-4b33-80a4-2c31b639e5b3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02c34d5b-16e9-412e-a385-ccd8cbceae16.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02c34d5b-16e9-412e-a385-ccd8cbceae16.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02e93c9a-c063-4bf2-9fa1-cb26692d58f8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02ea6b76-4189-47c5-a8bf-70590f84ebd8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\02ea6b76-4189-47c5-a8bf-70590f84ebd8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03249840-0a17-448c-bf41-7e156428ab59.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03249840-0a17-448c-bf41-7e156428ab59.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\035789b1-3736-405d-9910-f8f23c62ae9f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\035789b1-3736-405d-9910-f8f23c62ae9f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03a9498c-549d-4e7d-800b-e74797f7f625.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03a9498c-549d-4e7d-800b-e74797f7f625.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03a9498c-549d-4e7d-800b-e74797f7f625.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03ae75b6-45a7-4a68-9871-f07b82b17bf6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03ae75b6-45a7-4a68-9871-f07b82b17bf6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03cd7a5b-d5d7-40a1-81b1-c4264920530a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03cd7a5b-d5d7-40a1-81b1-c4264920530a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03d92597-3e33-4fdf-8db5-a27cf5b8d3eb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03e9a70f-3de8-4e13-b3f2-9dd6d75f496d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03e9a70f-3de8-4e13-b3f2-9dd6d75f496d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03edb5ed-9e76-4abe-bc35-7bc95fea7e6a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\03edb5ed-9e76-4abe-bc35-7bc95fea7e6a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\040a0743-f663-4746-8224-f0e3bacc7ba5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\040a0743-f663-4746-8224-f0e3bacc7ba5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\040a0743-f663-4746-8224-f0e3bacc7ba5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0499513a-5d48-4cf9-aac8-115e2a52fe1a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0499513a-5d48-4cf9-aac8-115e2a52fe1a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\049d7317-5a8b-4fc4-b81f-159fe6b45a92.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\04a6aa6d-bd6d-48b1-822b-21b81c4bdf3a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\04d59a79-e659-49ca-8790-511f89ac3e1b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\04dd9347-6215-4b34-a98f-a73e577aff9d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05083068-f4df-464a-b669-3c084ee05f1f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\051e6e97-fda7-4b5c-8d5f-084bf3607d22.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0587782c-ac6b-4ae1-8ffb-ce894d09f75e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\059f1e59-573c-49d1-ac78-3323a2ff047f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05b91b32-5635-4071-b45d-6a73f8eea918.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05b91b32-5635-4071-b45d-6a73f8eea918.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05b970e1-b223-4c17-a6a8-3f78c43c5308.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05b970e1-b223-4c17-a6a8-3f78c43c5308.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05bb6f8d-453b-4e56-ae92-2600e058ba65.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05bb6f8d-453b-4e56-ae92-2600e058ba65.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05d3817a-5535-4e77-8dda-d4412e496c81.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05d3817a-5535-4e77-8dda-d4412e496c81.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05d4d725-02a2-4c90-8ef8-463217889ba8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05d4d725-02a2-4c90-8ef8-463217889ba8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05dad446-45f7-44df-bd2f-4673d9502348.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05ead813-3c04-4e42-a5e1-4ca43294ece9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05eebe4c-bca2-40d4-bb20-54fc60e2bcea.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05eebe4c-bca2-40d4-bb20-54fc60e2bcea.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05fb0374-ab2d-4cf4-bb36-ce56fb2c28a5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05fe70c1-4cc1-42fb-9303-083fd29dac0f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05fe7d73-5c8c-4349-88c4-2071a00d6d81.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\05fe7d73-5c8c-4349-88c4-2071a00d6d81.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06089341-a69b-4777-817b-041be894b436.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06089341-a69b-4777-817b-041be894b436.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06155af4-88f1-48b3-8860-27578f1b2e04.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\061664a4-6a23-4cb2-a0da-0c5712b6e0a6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\061664a4-6a23-4cb2-a0da-0c5712b6e0a6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0618a5bc-196d-4afc-9ac4-d0aa940c6e03.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\061b44ff-fd22-473d-853f-81da70e14a63.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\061bb9bf-13c6-4ea0-bd82-5768fb83dff8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\061bb9bf-13c6-4ea0-bd82-5768fb83dff8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\061d0ff4-a611-42ce-b780-1d1eb55e50ab.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\061d0ff4-a611-42ce-b780-1d1eb55e50ab.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0620afa3-b2ea-442e-9e4f-c854086ca763.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06250f9d-5ad9-44ca-9283-dbf787e2ad22.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06250f9d-5ad9-44ca-9283-dbf787e2ad22.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06327569-4e4f-4fdc-a116-db367c079669.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0637b804-e693-48d1-8716-f7c63ce6162a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0638709c-d31d-4a59-a9e4-fc408ae36145.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0638709c-d31d-4a59-a9e4-fc408ae36145.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\063fed6c-4ecd-4a74-8f0d-c7a906a3afa4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\063fed6c-4ecd-4a74-8f0d-c7a906a3afa4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06420c87-02ee-4315-aa3a-63e911174435.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06420c87-02ee-4315-aa3a-63e911174435.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06550cfd-e9d5-415e-bae9-3146329ed9e6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06550cfd-e9d5-415e-bae9-3146329ed9e6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06634f15-9c78-47a1-97eb-f10f4c210765.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06634f15-9c78-47a1-97eb-f10f4c210765.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06697be9-b1ab-444c-af0d-fd11a053f2b3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06697be9-b1ab-444c-af0d-fd11a053f2b3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\066d9e27-e48f-4453-b1e1-d73c34910722.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06737bed-8dc1-47d9-8c30-324282dcc84d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06893030-14ab-456d-a22d-05070773e370.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06893030-14ab-456d-a22d-05070773e370.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\068b608d-f71c-4859-b909-62c1665b507f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0695a0d8-d4b6-4dbe-bc04-497897e4516a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0695a0d8-d4b6-4dbe-bc04-497897e4516a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0697baae-e475-4fa3-ad82-51b319a026cc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0697baae-e475-4fa3-ad82-51b319a026cc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06a07f16-f6b5-4ae5-8f68-a97131fe4701.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06a07f16-f6b5-4ae5-8f68-a97131fe4701.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06a4f477-34ca-4625-945b-81bfa9e77273.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06ac3c8c-cd1f-4e10-ac24-4cb4f3ab1243.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06b52ffd-71b8-429a-a284-bb39240ed343.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06b52ffd-71b8-429a-a284-bb39240ed343.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06b64e36-9e61-4865-bfe4-d96eef86548c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06bc1519-c307-4a98-b00b-8329f2ddf615.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06bc1519-c307-4a98-b00b-8329f2ddf615.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06bf9151-5732-4968-b198-f4109676cd55.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06c3e09b-341b-4fb9-9e28-bfd9cf298c6d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06c50ad5-8ffd-480b-8424-dd38df7ca86c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06cc46b7-50b1-41c1-a406-ccac7a5ac3e2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06cc46b7-50b1-41c1-a406-ccac7a5ac3e2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06cc9b59-b8ff-4a6b-9e5b-f127c7c1208d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06cf339f-a71a-4177-b950-ae1fdd5f4762.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06cf339f-a71a-4177-b950-ae1fdd5f4762.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06d3f696-82ea-4c71-b162-f18b3e0eeeac.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06d5a58d-baf1-4937-bfc3-00db1fb2b1be.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06d5a58d-baf1-4937-bfc3-00db1fb2b1be.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06d6e209-0bd4-45d4-81b4-4b97546d57fa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06d6e209-0bd4-45d4-81b4-4b97546d57fa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06df5d57-6f34-43c0-99ad-b9b5f9346cbd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06df5d57-6f34-43c0-99ad-b9b5f9346cbd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06e09ebb-cb5b-4c30-8d3a-67a6ec34692b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06e09ebb-cb5b-4c30-8d3a-67a6ec34692b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06ec9278-5144-4b88-87f4-c195bb24857d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06efb50a-e30e-4e44-b323-c228c66d80a6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06efb50a-e30e-4e44-b323-c228c66d80a6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06f35e64-4b8b-404e-933a-c98f0b5614cc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06f35e64-4b8b-404e-933a-c98f0b5614cc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06f5a38a-e4b1-4e5f-8c62-f48630a52504.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06fc2885-127a-4274-b20c-554d352ea21b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\06fc2885-127a-4274-b20c-554d352ea21b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0702a884-c189-4a05-bcf5-dc72f4f406fc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0702a884-c189-4a05-bcf5-dc72f4f406fc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07075b45-c83b-4e9a-971e-4b6c4554a0ef.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07075b45-c83b-4e9a-971e-4b6c4554a0ef.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\070c921f-171c-420c-915b-e49e3f600c38.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\070c921f-171c-420c-915b-e49e3f600c38.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\071206e7-d4c0-418d-9d06-ef6505ee5316.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\071206e7-d4c0-418d-9d06-ef6505ee5316.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\072e7048-52f1-4b2b-be08-42e0ca1ba1ee.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\072e7048-52f1-4b2b-be08-42e0ca1ba1ee.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\073102b7-565c-460a-9b69-13e2f34c4ee9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\073102b7-565c-460a-9b69-13e2f34c4ee9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07332989-6518-4bd9-96de-f4513948cf4a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07349035-d546-41ec-813a-612614536f5a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\073630e6-3b52-4b41-a14b-bf8bb57e28ea.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\073630e6-3b52-4b41-a14b-bf8bb57e28ea.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0742a7f3-5f8e-474b-bd1f-0ba8ba9a6b19.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0742a7f3-5f8e-474b-bd1f-0ba8ba9a6b19.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07464097-0781-4632-90ee-39b0e53cd72c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07464097-0781-4632-90ee-39b0e53cd72c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\074f8729-c5ea-4830-8249-9a04208eab5e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\074f8729-c5ea-4830-8249-9a04208eab5e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\074f91b5-e915-4b6f-bdf0-af1ee55ebd9b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\074f91b5-e915-4b6f-bdf0-af1ee55ebd9b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\076eab63-d75d-4272-a5d3-13eae02f2c8f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\076eab63-d75d-4272-a5d3-13eae02f2c8f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\077780cb-eb05-478f-a7d7-f0576e4c34df.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\077780cb-eb05-478f-a7d7-f0576e4c34df.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\077ff78d-27ef-49d4-9e8e-00e458844a3e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\077ff78d-27ef-49d4-9e8e-00e458844a3e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0798f0c3-bf7d-4f04-bd5e-b119163ea1b0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0798f0c3-bf7d-4f04-bd5e-b119163ea1b0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07a35aa8-491e-49f2-a9a3-13df10f32484.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07b7b9b0-718a-4750-b1f4-5af45c5607f2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07b7b9b0-718a-4750-b1f4-5af45c5607f2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07bb7f0d-ef4b-4963-b453-7f9d8c5b7c62.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07c379f0-8ceb-4ba9-84be-cfbb29de8ba5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07c99b1f-cf0c-40da-8ea9-8c5c9cd51189.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07c99b1f-cf0c-40da-8ea9-8c5c9cd51189.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07d1a89d-351c-4a75-993a-ba315142b419.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07d8eecd-8160-4f1f-8e26-d35de039cef6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07d8eecd-8160-4f1f-8e26-d35de039cef6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\07f78db5-7d9a-4ba0-a00f-02c36953020f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0808c4af-9ed6-46e3-a936-2cafb0004e6a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0808c4af-9ed6-46e3-a936-2cafb0004e6a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\080f2b35-fcd5-473e-864b-a7dea3054cc7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\080f2b35-fcd5-473e-864b-a7dea3054cc7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0812652c-3d92-4cda-9a06-c9d232e0b96d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\081a1f56-6c47-4b80-988a-3d357c977d65.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\081a1f56-6c47-4b80-988a-3d357c977d65.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\081a54bb-0144-4c22-9909-e3e45b15ff4c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\082fb468-30f1-43c1-ac04-62d16fdd883b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\082fb468-30f1-43c1-ac04-62d16fdd883b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\082fd63e-aec4-401a-822b-eb10d98b562c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\082fd63e-aec4-401a-822b-eb10d98b562c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08307845-ccbd-4616-b8e9-58532a766dbe.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\083a1a20-f642-42e3-b20b-937383f6da3c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\083a1a20-f642-42e3-b20b-937383f6da3c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\084aa98a-91aa-45d8-aa52-4fad8344b0bf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\084aa98a-91aa-45d8-aa52-4fad8344b0bf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\084d42b9-0a43-490d-9a8d-e4d7545c44f5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0851431b-cad7-436f-acb8-06aed97e5339.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0851431b-cad7-436f-acb8-06aed97e5339.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08542d41-e606-41df-b08c-9527b531f13f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08542d41-e606-41df-b08c-9527b531f13f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\085a25eb-1ebd-4bf1-b320-7833e7c37553.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\085a25eb-1ebd-4bf1-b320-7833e7c37553.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\085a6486-c3b3-4ca2-80f1-be07d23e853b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\085a6486-c3b3-4ca2-80f1-be07d23e853b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\085a6486-c3b3-4ca2-80f1-be07d23e853b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0862f2ff-7e56-4cd1-8c26-c3f25a86d257.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0862f2ff-7e56-4cd1-8c26-c3f25a86d257.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08725d04-9db2-4b52-87fe-6cdb150a4bb3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08725d04-9db2-4b52-87fe-6cdb150a4bb3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\087bcaa5-2477-4111-8390-fa5f2dec4852.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\088b89f6-6847-4a20-b1ad-5887b56bbae7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\088d4414-e057-45cb-a206-4dd3bb02dd6c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\088d4414-e057-45cb-a206-4dd3bb02dd6c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\089a996e-425c-4311-b473-6948b3eb1060.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08ab87a3-886f-4b5a-9818-889337c63d0b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08ab87a3-886f-4b5a-9818-889337c63d0b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08af877f-f833-4d4f-b64c-24e014d63311.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08b0056b-c563-4b30-9101-2ed685fdad1f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08b0056b-c563-4b30-9101-2ed685fdad1f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08b1c32d-e070-4a2c-9d75-f41055b7273b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08b1c32d-e070-4a2c-9d75-f41055b7273b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08c343b6-9dc4-405b-87b3-b6534abcb990.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08c343b6-9dc4-405b-87b3-b6534abcb990.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08d8e57a-4835-445b-8c79-8dd31ab17819.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08d8e57a-4835-445b-8c79-8dd31ab17819.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08da8f40-b186-473b-9fa3-1caa4ecdc02b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08da8f40-b186-473b-9fa3-1caa4ecdc02b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08e84251-b9cc-47e7-9486-be7becdd1d84.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08e84251-b9cc-47e7-9486-be7becdd1d84.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08ee8fda-45f1-4f46-a5ac-315a8d4dd196.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08f17660-dc61-4a5d-b6fb-10dacc1e20a2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08f17660-dc61-4a5d-b6fb-10dacc1e20a2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08f1b734-cd93-42c0-b978-9e1e1021bb55.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08f1b734-cd93-42c0-b978-9e1e1021bb55.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08f580ca-6c0e-47ca-9759-851b3c0bb397.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08f580ca-6c0e-47ca-9759-851b3c0bb397.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\08f9a388-c195-4b33-8acd-e05d4da14585.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0902e0fc-fcf3-40b5-ac04-c3ecc14c2355.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0906c2ce-d3a7-43ad-af1b-1dadf70d8cc4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0906c2ce-d3a7-43ad-af1b-1dadf70d8cc4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0909a8b0-09e7-4a78-9bfb-417a61c6723c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09137a8c-017a-4bc3-8195-1d152b992cd0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09137a8c-017a-4bc3-8195-1d152b992cd0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09147009-39a9-497a-ac10-a07cf7126d58.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\091781dd-be2b-4517-9264-ade2f0c85487.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0918aae8-b873-4510-b975-c6e87df90f58.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0918aae8-b873-4510-b975-c6e87df90f58.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\091cc2b7-8ba6-4fce-8ae2-7547117dbddf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\091cc2b7-8ba6-4fce-8ae2-7547117dbddf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\091d75a8-e23e-4cb8-af67-10cb314077ec.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\091d75a8-e23e-4cb8-af67-10cb314077ec.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\091fa211-36c0-42a4-bd7d-c8bced664d9d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0927e819-9640-487d-a04e-f5d4732dbe0a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0930b0aa-25c2-4624-a3fc-9b60ba0b23f4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0930b0aa-25c2-4624-a3fc-9b60ba0b23f4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09326eb7-f4cb-4d8f-83c6-8ba7fb8b5ac7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0949d712-9d3c-424a-99b5-423a598d8b97.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\094eed38-9c5b-4042-936d-344ccec4c3cc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\094eed38-9c5b-4042-936d-344ccec4c3cc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0953df2c-f969-4fa1-a872-022475ecd5ef.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0953df2c-f969-4fa1-a872-022475ecd5ef.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\095d6b7c-fa53-4f06-90b9-5c5f76038f04.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\095d6b7c-fa53-4f06-90b9-5c5f76038f04.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\095edab1-09c6-4f83-931e-f0a33b77639c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0965f1e9-2905-40ef-8612-4984e2c7e9ea.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\096a447e-8908-432b-a713-a51d3cd2ae9e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0976dbc4-041f-4bb0-9110-3024d0786c8b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0976dbc4-041f-4bb0-9110-3024d0786c8b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\097788d4-cb88-4457-8e71-0ca7a3da2216.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0983ae59-b906-4fd5-a810-edfe0580fe3b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\098435af-3834-466a-b17a-038ac4f0e464.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09852193-d7df-4cce-a616-a536d5de5042.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09852193-d7df-4cce-a616-a536d5de5042.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09875c3b-c520-4b08-89b0-a7a7299c37b2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\098906c5-cf22-43d3-9f0d-90e88e602090.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\098906c5-cf22-43d3-9f0d-90e88e602090.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\098e14d4-3205-4c2d-a059-738f830c0aa5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\098e14d4-3205-4c2d-a059-738f830c0aa5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\098e14d4-3205-4c2d-a059-738f830c0aa5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09a22f6d-5717-4c48-bf4c-531db698aaac.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09a22f6d-5717-4c48-bf4c-531db698aaac.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09ac8fc5-e8ed-410e-b167-3abaf28f0e2c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09ac8fc5-e8ed-410e-b167-3abaf28f0e2c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09afc58a-053c-420e-b379-e331aec15a7f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09b0df7c-90bc-499d-a7c7-5474199da4e6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09b0df7c-90bc-499d-a7c7-5474199da4e6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09b2d54e-3a85-4efd-8204-ea73bc70c405.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09b2d54e-3a85-4efd-8204-ea73bc70c405.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09bfe52b-201a-435a-b04f-ada40a64b5b5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09c48ba8-4f0b-483c-85ec-9246d7cc6177.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09c48ba8-4f0b-483c-85ec-9246d7cc6177.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09cdcb9a-3768-4403-a85e-37a65711aec4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09cdcb9a-3768-4403-a85e-37a65711aec4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09d2a8d3-3ef9-4e91-8abe-d1c127747905.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09db0213-0ad3-4062-bc7b-9a82e5a74097.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09dc577c-4219-45cc-9d01-6b46978927a7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09dc577c-4219-45cc-9d01-6b46978927a7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09eed5c5-e0e9-463c-b6f7-24e2de881287.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09f0ac0a-2933-45fc-a937-c0da67f5fd0d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\09f0ac0a-2933-45fc-a937-c0da67f5fd0d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a03fbf6-3c9a-4e2e-89ce-c7629ae43a27.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a03fbf6-3c9a-4e2e-89ce-c7629ae43a27.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a0f91dc-6015-4342-b809-d19610854a21.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a15acdd-248c-47ff-abfc-d33f8a0cf417.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a15acdd-248c-47ff-abfc-d33f8a0cf417.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a2c130c-c536-4651-836d-95d07e9a89cf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a2f6cf6-1f45-44c8-bcf0-98a3b466b597.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a374967-8ef8-4d34-94cc-a06929836723.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a46eca3-e577-4c7f-a782-9d54754bf096.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a46eca3-e577-4c7f-a782-9d54754bf096.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a51f668-b7b1-4d8d-9ab9-de1f702f071a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a578f72-dced-4550-8851-d8005549b724.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a62df77-7459-4acc-9cca-a62c2cec4b0f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a62df77-7459-4acc-9cca-a62c2cec4b0f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a66f58c-f98d-41d1-89af-4e0136888e13.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a66f58c-f98d-41d1-89af-4e0136888e13.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a6a5956-58cf-4f17-9e39-7e0d17310f67.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a7162ad-b2bc-4132-b15a-7fdc80957618.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a825a59-c034-481c-b596-9c7f0bc42c2c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a825a59-c034-481c-b596-9c7f0bc42c2c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a8d486f-1aa6-4fcf-b7be-4bf04fc8628b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a8d486f-1aa6-4fcf-b7be-4bf04fc8628b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a8efdc1-1dff-4d65-8948-c56a5d74a906.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a9c4c04-5918-48da-9ba1-b2a3add66ae9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a9c4c04-5918-48da-9ba1-b2a3add66ae9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a9fd225-a33a-47de-849e-156933b21296.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0a9fd225-a33a-47de-849e-156933b21296.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0aa43663-a1f3-44cb-8ecc-9b36fbb0d778.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0aa43663-a1f3-44cb-8ecc-9b36fbb0d778.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ab261f9-4eb5-42ab-a9a5-e918904d6356.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ab261f9-4eb5-42ab-a9a5-e918904d6356.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ab261f9-4eb5-42ab-a9a5-e918904d6356.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ab261f9-4eb5-42ab-a9a5-e918904d6356.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ab601ca-5f86-498f-89ab-73208a353e40.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ab601ca-5f86-498f-89ab-73208a353e40.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ac2fb38-efab-454a-971e-d8349b8ad28d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ac2fb38-efab-454a-971e-d8349b8ad28d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ad9934b-bf35-497d-8082-1ecbc955d6de.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0adcbadd-6b95-4692-bdfb-6a03d51af237.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0adec32a-b360-4396-866f-f1abaca047dc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0adec32a-b360-4396-866f-f1abaca047dc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ae5dcc7-197d-4d59-991a-3b93f3a1e760.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ae738d0-5bdd-4ebf-9c1f-6b10a25be92a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ae738d0-5bdd-4ebf-9c1f-6b10a25be92a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ae82435-399e-4cf1-9d78-92d1c184178d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ae82435-399e-4cf1-9d78-92d1c184178d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0af9ad69-4d76-4de9-b93a-294478a97866.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0af9ad69-4d76-4de9-b93a-294478a97866.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0afeabf5-d5a3-454f-a50d-887f0d21106c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0afeabf5-d5a3-454f-a50d-887f0d21106c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0afeabf5-d5a3-454f-a50d-887f0d21106c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b0073e0-9c19-4da4-88f2-b3d2ebc6f1f4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b0073e0-9c19-4da4-88f2-b3d2ebc6f1f4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b1d5b23-c3ab-41b5-b82d-a16a3d6b5674.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b202292-a925-4706-963f-28fd16cef0c2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b2057bc-4c6d-4c90-8975-94c02392e460.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b2057bc-4c6d-4c90-8975-94c02392e460.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b2057bc-4c6d-4c90-8975-94c02392e460.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b323a31-28e6-45b2-a07c-cc9b60571053.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b3b1768-5926-4084-bed0-ad9ae886d13a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b3b1768-5926-4084-bed0-ad9ae886d13a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b5fa34f-5c96-4cc5-becc-317acdff3221.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b74faac-00a1-4958-9571-b5f7f9c52179.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b7a4fb2-adab-484b-a0f7-23f5111bc745.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b7a4fb2-adab-484b-a0f7-23f5111bc745.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b8e881f-67bc-4021-a02c-0087233e43aa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b8e881f-67bc-4021-a02c-0087233e43aa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0b8f8765-0406-447c-b873-7ac5ce8884aa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ba245bb-b2e4-49b1-8c63-576e38470708.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ba245bb-b2e4-49b1-8c63-576e38470708.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bae27f3-01d4-4223-adc5-d3264e0d9213.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bae27f3-01d4-4223-adc5-d3264e0d9213.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bbb1ff7-dba6-4d5b-affe-b3ca0050d965.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bbe0f92-940f-431a-b8c4-3b371ea7d9aa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bbe0f92-940f-431a-b8c4-3b371ea7d9aa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bc7f47a-ecea-4b66-811e-096004721a63.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bcfe7ee-ada5-48de-990b-2a2fd6c6ed15.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bcfe7ee-ada5-48de-990b-2a2fd6c6ed15.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bd68d89-6a56-4b5e-b2f5-1be2d3665f97.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bd68d89-6a56-4b5e-b2f5-1be2d3665f97.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0beac0c9-331a-4aad-9cec-099aff98c399.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bed2d9d-8a11-41d9-b312-41f8c93791f7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0befe74c-5802-4fd4-aa1a-e5487d685558.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bf1767e-263b-443d-935f-489fe858922b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bf44996-58da-4a12-8be1-da5c9b009975.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bf44996-58da-4a12-8be1-da5c9b009975.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bf44996-58da-4a12-8be1-da5c9b009975.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bf4c667-6fb1-4943-8e6a-f80914cca147.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0bf4c667-6fb1-4943-8e6a-f80914cca147.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c0da1cf-9514-4c21-9988-fb53c52528d1.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c0da1cf-9514-4c21-9988-fb53c52528d1.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c0dbae5-b0a7-43b7-a964-11e6bcf40ae9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c0dbae5-b0a7-43b7-a964-11e6bcf40ae9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c122fd9-6dc8-4224-baae-812ed5c4bd12.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c153d93-d65b-4d3e-90bc-8b26350e3476.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c153d93-d65b-4d3e-90bc-8b26350e3476.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c15e437-7eea-4ed1-b1d8-124f79cc1893.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c1d54d9-0197-40d9-9b07-d99b1e8aa8db.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c248828-72e2-43cf-8622-b5775c421fb1.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c248828-72e2-43cf-8622-b5775c421fb1.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c24e2a2-9fca-463a-a1fa-fbcda2712260.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c294ecf-23d6-4c56-b5e2-0482915cd102.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c294ecf-23d6-4c56-b5e2-0482915cd102.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c2e5286-bb2c-427f-98be-8fc3796383d5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c2e5286-bb2c-427f-98be-8fc3796383d5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c391e0f-9927-48ce-801f-02eb000f72c3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c391e0f-9927-48ce-801f-02eb000f72c3.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c4c0dd9-1685-48c3-a09e-817816695016.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c523b07-6025-4d80-9de3-f435fd92002a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c5dc7d1-7022-4e46-bc02-ff9999912edd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c5dc7d1-7022-4e46-bc02-ff9999912edd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c77d941-5f63-4e2a-9c1e-4a58043acd55.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c8199bc-2634-4196-b81b-4732adac9926.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c8458d8-25e6-44e5-946e-cf729240df59.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c8458d8-25e6-44e5-946e-cf729240df59.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c89ca38-27ca-4cd0-88cb-18093fdcb04b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0c8b3735-25e3-4628-bb53-8c24e10eec56.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ca3f31a-ace5-4bd2-9900-b152cc212c8e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ca8314a-88e7-4661-b5fd-3bdee5fc2616.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cac94e3-15f2-4657-beae-b508b5e0d176.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cb05380-5ae8-46de-8585-41b5323d7c65.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cb05380-5ae8-46de-8585-41b5323d7c65.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cb52e59-3b50-41fb-a022-5b24741dbcfc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cbc601f-91f0-4f86-b780-ffeac24471c7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cbe5298-68a4-4de0-a693-46eb8e8858ca.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cbf3284-5b78-4e23-bffd-e546f7e76da9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cc09b0a-1afc-4492-929e-ac53f15286b6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cc09b0a-1afc-4492-929e-ac53f15286b6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cc48c9c-0576-4d70-abc0-dd8cdc1eb788.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cc48c9c-0576-4d70-abc0-dd8cdc1eb788.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cc66f3f-6bfb-4f99-bbc6-ed28bf3f740c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ccff729-ee71-4a5f-ad01-ce12ab162afa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ccff729-ee71-4a5f-ad01-ce12ab162afa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cd3f245-763a-4db0-870d-3ee1a3c6bdcb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cd3f245-763a-4db0-870d-3ee1a3c6bdcb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cde91a5-9428-4746-8240-f34c720e24cd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0cde91a5-9428-4746-8240-f34c720e24cd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d2bc8b2-2340-4deb-b29c-ae4da8fa5764.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d2bc8b2-2340-4deb-b29c-ae4da8fa5764.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d587b82-827b-4e80-af20-4ee8207700ee.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d587b82-827b-4e80-af20-4ee8207700ee.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d5bc737-03de-4bb8-98a1-45b7180c3e0f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d5bc737-03de-4bb8-98a1-45b7180c3e0f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d5bc737-03de-4bb8-98a1-45b7180c3e0f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d5bc737-03de-4bb8-98a1-45b7180c3e0f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d77cf1a-64d4-4f8a-938b-9b838d549090.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d77cf1a-64d4-4f8a-938b-9b838d549090.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d9b1283-fc24-4fd3-a520-bc5d563e13e1.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d9b1901-494b-4b0a-a0a4-8f67273c56a7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d9f8e9e-3a29-472a-8a96-7c792d6f3edf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0d9f8e9e-3a29-472a-8a96-7c792d6f3edf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0daa445f-6b0b-499f-8162-91296e89f61c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0daa445f-6b0b-499f-8162-91296e89f61c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0db8b03b-efb4-4a92-9c82-39a5bfecb689.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0dcc2f61-2c28-4c66-a50c-9728cdab1ed9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e0cfa1a-c097-47bb-bf4b-6b9362940705.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e302d0d-b8c2-4d92-a735-12e843ff89df.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e302d0d-b8c2-4d92-a735-12e843ff89df.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e724a83-c104-4d33-94a5-c7df6174f40f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e724a83-c104-4d33-94a5-c7df6174f40f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e7d0fc9-9a11-4325-91b2-bb13e40d1f1a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e7d0fc9-9a11-4325-91b2-bb13e40d1f1a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0e91afec-c246-450b-9f10-e07a75ae0086.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ebc8268-df3d-45d8-8ee7-b34880c62830.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ebc8268-df3d-45d8-8ee7-b34880c62830.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\0ec6b85a-de25-4870-a100-0d7ca6c798bf.dcm
# ...
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27775937-404e-4e1a-bef0-af5d63fc0b3b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27775937-404e-4e1a-bef0-af5d63fc0b3b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27b32500-40ef-4c14-ab88-ace5e9ceea27.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27b32500-40ef-4c14-ab88-ace5e9ceea27.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27bdb2cc-9665-40ea-a6b4-248a1112dbe8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27ee75df-d2e3-40c0-994f-3efd14e6dafb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27ee75df-d2e3-40c0-994f-3efd14e6dafb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27fa7496-e222-4016-8d1a-5a8dd4db52ed.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27fa7496-e222-4016-8d1a-5a8dd4db52ed.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27feebaa-f4dc-4c68-9348-f0ff35134e43.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\27feebaa-f4dc-4c68-9348-f0ff35134e43.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\285e0dd4-4f19-47ab-9ce0-6b02c1396f29.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28684a2f-1e6f-4431-969a-2f9cf574e7ba.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28684a2f-1e6f-4431-969a-2f9cf574e7ba.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28775c77-80e8-4f8c-be85-7a44162b5c28.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28a2d8aa-9e29-48d4-b1e3-029e3451ce0b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28a2d8aa-9e29-48d4-b1e3-029e3451ce0b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28ba0617-0cac-4198-8b8a-c35fde545ace.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28ba0617-0cac-4198-8b8a-c35fde545ace.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28c94c54-4279-431a-b329-c69104ee0d38.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28dfbd38-b24a-4cfb-a355-34c226dd2aa2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\28fa453d-027a-4569-9e22-7814e7b74f43.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\29000617-ac33-40a4-ac5c-19fb586edb69.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\290e32e9-3632-4642-a1d4-70c975d376b7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\290e32e9-3632-4642-a1d4-70c975d376b7.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\29128fda-79ce-4a14-bbf9-9884422075d0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\29128fda-79ce-4a14-bbf9-9884422075d0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\292a1c21-012d-4039-b95e-02524e82bce1.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\293f4b7b-3a6e-44a6-b9d2-810b139094cf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\29bc3aa5-938c-4afe-8a7b-50ebd2cb5621.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\29bc3aa5-938c-4afe-8a7b-50ebd2cb5621.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\29cfef18-40c3-489f-adcf-05bd93765b9d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2a9035ed-ec09-404d-adc3-d37688adf50a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2a9035ed-ec09-404d-adc3-d37688adf50a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ac47932-d7e2-4ac2-a7c6-6a9be0c4abcd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ac47932-d7e2-4ac2-a7c6-6a9be0c4abcd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ac47932-d7e2-4ac2-a7c6-6a9be0c4abcd.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ae3e7ba-a0fe-4f0a-96db-d337714aa657.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2af2646f-3cc0-4ef2-a9e4-0beea36f335a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2af2646f-3cc0-4ef2-a9e4-0beea36f335a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2afaf9b4-664c-4c87-b9f5-4e411789da5d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2b4c09a2-c8d7-4773-84e3-f1aa664fba9a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2b55eeed-3408-46fd-9e18-d7c5295a92b2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2b885980-3f3c-452f-9ca6-af215dbfe61c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2b885980-3f3c-452f-9ca6-af215dbfe61c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ba20b8b-50aa-477d-8f39-ded35b460696.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2bb1db95-73ad-46b0-8567-8a03d9a83def.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2bd2356b-305a-4726-9a47-034da8f5f2ee.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2bd2f688-6bed-4f0c-a385-9eed1b1027de.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2bd2f688-6bed-4f0c-a385-9eed1b1027de.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2bdfab0d-4192-4a7f-a366-587c379ecdba.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2bdfab0d-4192-4a7f-a366-587c379ecdba.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2bf8a7ed-b4a5-4ea1-b8e8-cadc7f7adf2d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c376b9a-167a-43d3-bcc2-b4af32fb9f74.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c575dd0-1a23-40d1-a0b6-da6d9c2556ae.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c575dd0-1a23-40d1-a0b6-da6d9c2556ae.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c7411ab-ce18-469d-868f-de850cafa9ba.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c7411ab-ce18-469d-868f-de850cafa9ba.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c781913-5f24-4b0e-959c-6b7385c6fce0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c781913-5f24-4b0e-959c-6b7385c6fce0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c917d3a-95cb-4c11-802c-f83e28cb37bc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c917d3a-95cb-4c11-802c-f83e28cb37bc.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2c9a388f-0042-4b88-b52b-ea0b21fb7960.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cc72d62-1144-4fe9-a4ab-da083ad11392.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cc72d62-1144-4fe9-a4ab-da083ad11392.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cce4f3d-ad2a-4021-b46a-3f34015600e5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cce4f3d-ad2a-4021-b46a-3f34015600e5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cd0cbc4-bf35-49de-963e-8ee3fd08ca75.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cd0cbc4-bf35-49de-963e-8ee3fd08ca75.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cd0cbc4-bf35-49de-963e-8ee3fd08ca75.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ce34f96-40b4-4d2a-b6a1-c7e21e6db8a1.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2cfbc16c-f1e4-4ed2-b9eb-4d0c40b90800.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2d0ebb7e-9c57-4a78-9728-e79b0f2bc91c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2d370cb1-791e-407e-9408-9156664de6b6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2d519447-4bcf-42ad-bb28-cf051b649fff.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2d519447-4bcf-42ad-bb28-cf051b649fff.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2db5d817-4f4c-4773-afa0-ed3cdb3a5035.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2db5d817-4f4c-4773-afa0-ed3cdb3a5035.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2dd692a5-a60c-443e-8299-af5d03949b60.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2e02f4ce-3130-42b9-af78-997942bc4f38.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2e1956e1-8430-48d7-9888-910934acd22b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2e1956e1-8430-48d7-9888-910934acd22b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2e3363a0-19d9-47d7-b7e5-d2142da1b9fa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2e3363a0-19d9-47d7-b7e5-d2142da1b9fa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ef4cfe7-bbc1-4ce2-ba1e-6df54a94252c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2ef4cfe7-bbc1-4ce2-ba1e-6df54a94252c.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f200e3f-8e4c-4675-948c-8226cd65163a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f200e3f-8e4c-4675-948c-8226cd65163a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f42fe81-bd2a-4b14-966b-589873d13663.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f51b8c1-32f8-4df8-af1e-d32c8dddad6f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f51b8c1-32f8-4df8-af1e-d32c8dddad6f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f55c07d-beb7-4b5f-9e9d-18d4fed5ae27.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f6374c9-baec-4236-acb4-a3815dc8243a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f6374c9-baec-4236-acb4-a3815dc8243a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f686840-18b3-45ac-a2bb-6140e3b0ac73.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f686840-18b3-45ac-a2bb-6140e3b0ac73.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f686840-18b3-45ac-a2bb-6140e3b0ac73.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f9c1b97-74a7-4781-bad3-c46cc08c69c8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2f9c1b97-74a7-4781-bad3-c46cc08c69c8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2fa75092-e364-4326-b5b0-f1d61df464c8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2fa75092-e364-4326-b5b0-f1d61df464c8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2fa8e28a-dce6-4c68-8bb6-b2537476577d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2fc6c353-a51d-4eb7-ae51-d971f12a38d9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\2fc6c353-a51d-4eb7-ae51-d971f12a38d9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\30181ed4-6337-47e1-89b7-9dfe63c95131.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\30181ed4-6337-47e1-89b7-9dfe63c95131.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\303390de-3812-4aae-893f-3f18897a6c21.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\303390de-3812-4aae-893f-3f18897a6c21.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\30363e8f-2955-4a45-b6e5-8e7146d6c243.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\3036ca10-8d42-4749-81e2-8ed235a6a567.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\3040d9d7-d895-453f-887c-616c10531960.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\3041969c-8db3-448c-98fd-10ff11dd59d4.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\3066b0e3-9a51-4628-bc5f-82dc78c9d558.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\3066b0e3-9a51-4628-bc5f-82dc78c9d558.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\308cf5b6-fcaf-4673-bc75-737b8d67b889.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\308cf5b6-fcaf-4673-bc75-737b8d67b889.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\308e8db6-f833-45b2-adb7-0f019ff96135.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\30d44656-0af9-4870-b43c-f83de6cd8f2e.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\30f2c879-2104-45e4-acbd-6284f7a62d35.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\30f2c879-2104-45e4-acbd-6284f7a62d35.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\311a559e-bed5-478a-94f5-c1bcf1df939a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\311a559e-bed5-478a-94f5-c1bcf1df939a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\bfea966c-f72f-42f7-9712-9cf77b66bad6.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\bfefcd13-122d-4c6f-8f4f-5c53417165db.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\bfefcd13-122d-4c6f-8f4f-5c53417165db.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\bffde351-7ccf-49cd-aa8b-893c7d359e29.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\bffde351-7ccf-49cd-aa8b-893c7d359e29.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c02e993c-7642-4d8a-aace-988c416ec09a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c033f66d-900e-4ba3-8da4-a6823ea89d09.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c033f66d-900e-4ba3-8da4-a6823ea89d09.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c04f9256-7358-42ef-b843-19dbf64ef287.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c059ced8-e99a-4fff-a734-b01cae2491bb.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c0608b6d-a375-4cda-8133-b5ec73217435.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c0608b6d-a375-4cda-8133-b5ec73217435.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c0654897-6bfe-4b7c-abd3-dda76d0fcac2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c0654897-6bfe-4b7c-abd3-dda76d0fcac2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c068a37d-3fe7-4a26-bb74-575ea6be194d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c068a37d-3fe7-4a26-bb74-575ea6be194d.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c07f52df-d481-434f-84c1-04263926ac40.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c07f52df-d481-434f-84c1-04263926ac40.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c08f10a9-1c81-4c81-b411-a53c7b51f20b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c08f10a9-1c81-4c81-b411-a53c7b51f20b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c09b4889-d8d1-4690-806e-dfada1f79e0b.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c102bfc2-601d-4275-b986-d928bf170ef9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c102bfc2-601d-4275-b986-d928bf170ef9.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c106ddba-42f7-440c-9ba9-f3fa6692f06f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c106ddba-42f7-440c-9ba9-f3fa6692f06f.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c109061a-d815-4cae-8343-9230d8024adf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c109061a-d815-4cae-8343-9230d8024adf.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1273696-fdec-48a9-988c-74e57b6323fa.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c12aafdd-4d21-4cd3-a2ae-007bce2e2fc0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1415e26-fddf-4a0c-a7eb-7b9a0d9e9983.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1415e26-fddf-4a0c-a7eb-7b9a0d9e9983.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c145df8e-9631-468d-af7f-5690c11c2c88.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c145df8e-9631-468d-af7f-5690c11c2c88.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c14d9ceb-019f-45f6-9299-281b58de57df.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c14d9ceb-019f-45f6-9299-281b58de57df.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1628c47-5ba3-42dd-8df3-7ad3abd57ad0.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c18d1138-ba74-4af5-af21-bdd4d2c96bb5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c18d1138-ba74-4af5-af21-bdd4d2c96bb5.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1cddf32-b957-4753-acaa-472ab1447e86.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1cddf32-b957-4753-acaa-472ab1447e86.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1e73a4e-7afe-4ec5-8af6-ce8315d7a2f2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1e73a4e-7afe-4ec5-8af6-ce8315d7a2f2.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1ec14ff-f6d7-4b38-b0cb-fe07041cbdc8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1ec14ff-f6d7-4b38-b0cb-fe07041cbdc8.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1f7889a-9ea9-4acb-b64c-b737c929599a.dcm
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\c1f7889a-9ea9-4acb-b64c-b737c929599a.dcm

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# show dicom fields 
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.276.0.7230010.3.1.4.8323329.6379.1517874325.469569
# (0002, 0010) Transfer Syntax UID                 UI: JPEG Baseline (Process 1)
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.0
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_360'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.6379.1517874325.469569
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: '00436515-870c-4b36-a041-de91049b9ab4'
# (0010, 0020) Patient ID                          LO: '00436515-870c-4b36-a041-de91049b9ab4'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '32'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'AP'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.6379.1517874325.469568
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.6379.1517874325.469567
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: "1"
# (0020, 0013) Instance Number                     IS: "1"
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: [0.139, 0.139]
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 119382 elements

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets

# %%
image_fps_list = list(image_fps)
random.seed(42)
random.shuffle(image_fps_list)
val_size = 1500
image_fps_val = image_fps_list[:val_size]
image_fps_train = image_fps_list[val_size:]

print(len(image_fps_train), len(image_fps_val))
# print(image_fps_val[:6])
# Out:
# 4512 1500

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %% [markdown]
# ### Let's look at a sample annotation. We see a bounding box with (x, y) of the the top left corner as well as the width and height.

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    3af465f7-7be0-4b58-969b-943499e00946
#  x                                             599
#  y                                             498
#  width                                         266
#  height                                        355
#  Target                                          1
#  Name: 3829, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random sample and their bounding boxes

class_ids = [0]
while class_ids[0] == 0:  ## look for a mask
    image_id = random.choice(dataset_train.image_ids)
    image_fp = dataset_train.image_reference(image_id)
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# D:\AIML PROJ\MASK_RCNN\MASK_RCNN\stage_2_train_images\a175b2d8-ebdf-4643-8afa-8a4566766f75.dcm
# [1 1]

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
# Image augmentation (light but constant)
augmentation = iaa.Sequential([
    iaa.OneOf([ ## geometric transform
        iaa.Affine(
            scale={"x": (0.98, 1.02), "y": (0.98, 1.04)},
            translate_percent={"x": (-0.02, 0.02), "y": (-0.04, 0.04)},
            rotate=(-2, 2),
            shear=(-1, 1),
        ),
        iaa.PiecewiseAffine(scale=(0.001, 0.025)),
    ]),
    iaa.OneOf([ ## brightness or contrast
        iaa.Multiply((0.9, 1.1)),
        iaa.ContrastNormalization((0.9, 1.1)),
    ]),
    iaa.OneOf([ ## blur or sharpen
        iaa.GaussianBlur(sigma=(0.0, 0.1)),
        iaa.Sharpen(alpha=(0.0, 0.1)),
    ]),
])

# test on the same image as above
imggrid = augmentation.draw_grid(image[:, :, 0], cols=5, rows=2)
plt.figure(figsize=(30, 12))
_ = plt.imshow(imggrid[:, :, 0], cmap='gray')

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %% [markdown]
# **initial_epoch**
# ```python
#
# self.keras_model.fit_generator(
#             train_generator,
#             initial_epoch=self.epoch,
#             epochs=epochs,
#             steps_per_epoch=self.config.STEPS_PER_EPOCH,
#             callbacks=callbacks,
#             validation_data=val_generator,
#             validation_steps=self.config.VALIDATION_STEPS,
#             max_queue_size=100,
#             workers=workers,
#             use_multiprocessing=True,
#         )
#         self.epoch = max(self.epoch, epochs)
# ```
#
# ```python
# return training_generator.fit_generator(
#             self, generator,
#             steps_per_epoch=steps_per_epoch,
#             epochs=epochs,
#             verbose=verbose,
#             callbacks=callbacks,
#             validation_data=validation_data,
#             validation_steps=validation_steps,
#             class_weight=class_weight,
#             max_queue_size=max_queue_size,
#             workers=workers,
#             use_multiprocessing=use_multiprocessing,
#             shuffle=shuffle,
#             initial_epoch=initial_epoch)
# ```
# ```python
# # Construct epoch logs.
#         epoch_logs = {}
#         while epoch < epochs:
#             for m in model.stateful_metric_functions:
#                 m.reset_states()
#             callbacks.on_epoch_begin(epoch)
#             steps_done = 0
#             batch_index = 0
#             while steps_done < steps_per_epoch:
# ```
#
# | initial_epoch| epochs | logs               |
# | -------------|--------|--------------------|
# | 0            | 2      |Epoch 1/2 to 2/2    |
# | 2            | 6      |Epoch 3/6 to 6/6    |
# | 6            | 16     |Epoch 7/16 to 16/16 |

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# Exclude the last layers because they require a matching
# number of classes
model.load_weights(COCO_WEIGHTS_PATH, by_name=True, exclude=[
    "mrcnn_class_logits", "mrcnn_bbox_fc",
    "mrcnn_bbox", "mrcnn_mask"])

# %%
LEARNING_RATE = 0.006

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")

# %%
# %%time
## train heads with higher lr to speedup the learning
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE*2,
            epochs=2,
            layers='heads',
            augmentation=None)  ## no need to augment yet

history = model.keras_model.history.history
# Out:
# Starting at epoch 0. LR=0.012
#
# Checkpoint Path: checkpoints/pneumonia20181106T1102/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/2
# 200/200 [==============================] - 189s 944ms/step - loss: 1.6303 - rpn_class_loss: 0.0191 - rpn_bbox_loss: 0.4851 - mrcnn_class_loss: 0.2652 - mrcnn_bbox_loss: 0.4568 - mrcnn_mask_loss: 0.4041 - val_loss: 2.5401 - val_rpn_class_loss: 0.0187 - val_rpn_bbox_loss: 1.2545 - val_mrcnn_class_loss: 0.2577 - val_mrcnn_bbox_loss: 0.5634 - val_mrcnn_mask_loss: 0.4458
# Epoch 2/2
# 200/200 [==============================] - 108s 542ms/step - loss: 1.6265 - rpn_class_loss: 0.0183 - rpn_bbox_loss: 0.5487 - mrcnn_class_loss: 0.2613 - mrcnn_bbox_loss: 0.4125 - mrcnn_mask_loss: 0.3857 - val_loss: 2.2840 - val_rpn_class_loss: 0.0271 - val_rpn_bbox_loss: 1.1811 - val_mrcnn_class_loss: 0.2023 - val_mrcnn_bbox_loss: 0.4680 - val_mrcnn_mask_loss: 0.4055
# CPU times: user 4min 20s, sys: 18.2 s, total: 4min 39s
# Wall time: 5min 51s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE,
            epochs=6,
            layers='all',
            augmentation=augmentation)

new_history = model.keras_model.history.history
for k in new_history: history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 2. LR=0.006
#
# Checkpoint Path: checkpoints/pneumonia20181106T1102/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 3/6
# 200/200 [==============================] - 302s 2s/step - loss: 1.4542 - rpn_class_loss: 0.0182 - rpn_bbox_loss: 0.4543 - mrcnn_class_loss: 0.2145 - mrcnn_bbox_loss: 0.3795 - mrcnn_mask_loss: 0.3876 - val_loss: 2.1487 - val_rpn_class_loss: 0.0197 - val_rpn_bbox_loss: 1.1350 - val_mrcnn_class_loss: 0.1737 - val_mrcnn_bbox_loss: 0.4080 - val_mrcnn_mask_loss: 0.4123
# Epoch 4/6
# 200/200 [==============================] - 258s 1s/step - loss: 1.3135 - rpn_class_loss: 0.0141 - rpn_bbox_loss: 0.3762 - mrcnn_class_loss: 0.2043 - mrcnn_bbox_loss: 0.3417 - mrcnn_mask_loss: 0.3772 - val_loss: 1.8318 - val_rpn_class_loss: 0.0190 - val_rpn_bbox_loss: 0.8017 - val_mrcnn_class_loss: 0.2163 - val_mrcnn_bbox_loss: 0.4036 - val_mrcnn_mask_loss: 0.3913
# Epoch 5/6
# 200/200 [==============================] - 237s 1s/step - loss: 1.2977 - rpn_class_loss: 0.0132 - rpn_bbox_loss: 0.3562 - mrcnn_class_loss: 0.1981 - mrcnn_bbox_loss: 0.3550 - mrcnn_mask_loss: 0.3752 - val_loss: 2.4519 - val_rpn_class_loss: 0.0237 - val_rpn_bbox_loss: 1.3731 - val_mrcnn_class_loss: 0.1603 - val_mrcnn_bbox_loss: 0.4702 - val_mrcnn_mask_loss: 0.4247
# Epoch 6/6
# 200/200 [==============================] - 261s 1s/step - loss: 1.3963 - rpn_class_loss: 0.0134 - rpn_bbox_loss: 0.3944 - mrcnn_class_loss: 0.2397 - mrcnn_bbox_loss: 0.3649 - mrcnn_mask_loss: 0.3840 - val_loss: 1.7298 - val_rpn_class_loss: 0.0195 - val_rpn_bbox_loss: 0.6438 - val_mrcnn_class_loss: 0.2513 - val_mrcnn_bbox_loss: 0.4282 - val_mrcnn_mask_loss: 0.3870
# CPU times: user 7min 59s, sys: 39.8 s, total: 8min 39s
# Wall time: 18min 24s

# %%
# %%time
model.train(dataset_train, dataset_val,
            learning_rate=LEARNING_RATE/5,
            epochs=16,
            layers='all',
            augmentation=augmentation)

new_history = model.keras_model.history.history
for k in new_history: history[k] = history[k] + new_history[k]
# Out:
# Starting at epoch 6. LR=0.0012000000000000001
#
# Checkpoint Path: checkpoints/pneumonia20181106T1102/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 7/16
# 200/200 [==============================] - 313s 2s/step - loss: 1.3738 - rpn_class_loss: 0.0130 - rpn_bbox_loss: 0.3723 - mrcnn_class_loss: 0.2314 - mrcnn_bbox_loss: 0.3721 - mrcnn_mask_loss: 0.3849 - val_loss: 1.5178 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.5372 - val_mrcnn_class_loss: 0.1779 - val_mrcnn_bbox_loss: 0.3997 - val_mrcnn_mask_loss: 0.3904
# Epoch 8/16
# 200/200 [==============================] - 239s 1s/step - loss: 1.2896 - rpn_class_loss: 0.0103 - rpn_bbox_loss: 0.3247 - mrcnn_class_loss: 0.2397 - mrcnn_bbox_loss: 0.3372 - mrcnn_mask_loss: 0.3778 - val_loss: 2.1638 - val_rpn_class_loss: 0.0225 - val_rpn_bbox_loss: 1.0176 - val_mrcnn_class_loss: 0.2908 - val_mrcnn_bbox_loss: 0.4310 - val_mrcnn_mask_loss: 0.4019
# Epoch 9/16
# 200/200 [==============================] - 230s 1s/step - loss: 1.2425 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 0.2956 - mrcnn_class_loss: 0.2166 - mrcnn_bbox_loss: 0.3392 - mrcnn_mask_loss: 0.3796 - val_loss: 1.7889 - val_rpn_class_loss: 0.0158 - val_rpn_bbox_loss: 0.8380 - val_mrcnn_class_loss: 0.1839 - val_mrcnn_bbox_loss: 0.3759 - val_mrcnn_mask_loss: 0.3753
# Epoch 10/16
# 200/200 [==============================] - 245s 1s/step - loss: 1.1291 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.2723 - mrcnn_class_loss: 0.1888 - mrcnn_bbox_loss: 0.2984 - mrcnn_mask_loss: 0.3600 - val_loss: 1.9083 - val_rpn_class_loss: 0.0163 - val_rpn_bbox_loss: 0.8548 - val_mrcnn_class_loss: 0.2182 - val_mrcnn_bbox_loss: 0.4187 - val_mrcnn_mask_loss: 0.4004
# Epoch 11/16
# 200/200 [==============================] - 222s 1s/step - loss: 2705515326997.8062 - rpn_class_loss: 0.0113 - rpn_bbox_loss: 0.3610 - mrcnn_class_loss: 2080132185456.8701 - mrcnn_bbox_loss: 625383141540.1871 - mrcnn_mask_loss: 0.3776 - val_loss: 1.7287 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.7525 - val_mrcnn_class_loss: 0.1973 - val_mrcnn_bbox_loss: 0.3833 - val_mrcnn_mask_loss: 0.3805
# Epoch 12/16
# 200/200 [==============================] - 227s 1s/step - loss: 1.4208 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.3923 - mrcnn_class_loss: 0.2566 - mrcnn_bbox_loss: 0.3730 - mrcnn_mask_loss: 0.3878 - val_loss: 1.5404 - val_rpn_class_loss: 0.0121 - val_rpn_bbox_loss: 0.5403 - val_mrcnn_class_loss: 0.2000 - val_mrcnn_bbox_loss: 0.3919 - val_mrcnn_mask_loss: 0.3961
# Epoch 13/16
# 200/200 [==============================] - 227s 1s/step - loss: 1.3020 - rpn_class_loss: 0.0111 - rpn_bbox_loss: 0.3509 - mrcnn_class_loss: 0.2045 - mrcnn_bbox_loss: 0.3507 - mrcnn_mask_loss: 0.3847 - val_loss: 1.7489 - val_rpn_class_loss: 0.0151 - val_rpn_bbox_loss: 0.7932 - val_mrcnn_class_loss: 0.1389 - val_mrcnn_bbox_loss: 0.4078 - val_mrcnn_mask_loss: 0.3939
# Epoch 14/16
# 200/200 [==============================] - 238s 1s/step - loss: 1.3783 - rpn_class_loss: 0.0103 - rpn_bbox_loss: 0.3715 - mrcnn_class_loss: 0.2464 - mrcnn_bbox_loss: 0.3697 - mrcnn_mask_loss: 0.3803 - val_loss: 1.5642 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.3886 - val_mrcnn_class_loss: 0.3176 - val_mrcnn_bbox_loss: 0.4487 - val_mrcnn_mask_loss: 0.3994
# Epoch 15/16
# 200/200 [==============================] - 219s 1s/step - loss: 1.2883 - rpn_class_loss: 0.0102 - rpn_bbox_loss: 0.3643 - mrcnn_class_loss: 0.2047 - mrcnn_bbox_loss: 0.3405 - mrcnn_mask_loss: 0.3685 - val_loss: 1.6666 - val_rpn_class_loss: 0.0145 - val_rpn_bbox_loss: 0.6816 - val_mrcnn_class_loss: 0.1905 - val_mrcnn_bbox_loss: 0.4079 - val_mrcnn_mask_loss: 0.3721
# Epoch 16/16
# 200/200 [==============================] - 232s 1s/step - loss: 1.2824 - rpn_class_loss: 0.0093 - rpn_bbox_loss: 0.3366 - mrcnn_class_loss: 0.2228 - mrcnn_bbox_loss: 0.3460 - mrcnn_mask_loss: 0.3676 - val_loss: 1.4254 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.5435 - val_mrcnn_class_loss: 0.1794 - val_mrcnn_bbox_loss: 0.3311 - val_mrcnn_mask_loss: 0.3603
# CPU times: user 13min 3s, sys: 1min 36s, total: 14min 39s
# Wall time: 41min 33s

# %%
epochs = range(1,len(next(iter(history.values())))+1)
pd.DataFrame(history, index=epochs)
# Out:
#     val_loss  val_rpn_class_loss  val_rpn_bbox_loss  val_mrcnn_class_loss  \
# 1   2.540091            0.018674           1.254547              0.257674
# 2   2.283956            0.027055           1.181051              0.202297
# 3   2.148677            0.019687           1.135029              0.173679
# 4   1.831769            0.018980           0.801667              0.216305
# 5   2.451927            0.023686           1.373085              0.160277
# 6   1.729832            0.019475           0.643793              0.251315
# 7   1.517785            0.012593           0.537160              0.177868
# 8   2.163764            0.022462           1.017580              0.290819
# 9   1.788917            0.015824           0.838013              0.183936
# 10  1.908346            0.016310           0.854768              0.218175
# 11  1.728687            0.015040           0.752526              0.197270
# 12  1.540432            0.012092           0.540252              0.200039
# 13  1.748926            0.015120           0.793230              0.138856
# 14  1.564160            0.009890           0.388600              0.317552
# 15  1.666580            0.014510           0.681579              0.190461
# 16  1.425401            0.011084           0.543452              0.179435
#
#     val_mrcnn_bbox_loss  val_mrcnn_mask_loss          loss  rpn_class_loss  \
# 1              0.563426             0.445767  1.630324e+00        0.019122
# 2              0.468021             0.405528  1.626453e+00        0.018317
# 3              0.407956             0.412315  1.454195e+00        0.018169
# 4              0.403551             0.391254  1.313539e+00        0.014090
# 5              0.470208             0.424660  1.297686e+00        0.013158
# 6              0.428197             0.387038  1.396347e+00        0.013371
# 7              0.399717             0.390434  1.373763e+00        0.013029
# 8              0.430976             0.401914  1.289565e+00        0.010260
# 9              0.375877             0.375254  1.242496e+00        0.011437
# 10             0.418723             0.400357  1.129115e+00        0.009696
# 11             0.383318             0.380519  2.705515e+12        0.011329
# 12             0.391931             0.396105  1.420790e+00        0.011050
# 13             0.407846             0.393860  1.301952e+00        0.011098
# 14             0.448743             0.399361  1.378319e+00        0.010332
# 15             0.407916             0.372099  1.288325e+00        0.010200
# 16             0.331144             0.360272  1.282411e+00        0.009287
#
#     rpn_bbox_loss  mrcnn_class_loss  mrcnn_bbox_loss  mrcnn_mask_loss
# 1        0.485085      2.652248e-01     4.568024e-01         0.404088
# 2        0.548700      2.612766e-01     4.124919e-01         0.385665
# 3        0.454328      2.145162e-01     3.795348e-01         0.387636
# 4        0.376216      2.043105e-01     3.417401e-01         0.377170
# 5        0.356205      1.981279e-01     3.550233e-01         0.375161
# 6        0.394375      2.397359e-01     3.648884e-01         0.383965
# 7        0.372345      2.313761e-01     3.721396e-01         0.384860
# 8        0.324654      2.396738e-01     3.371923e-01         0.377772
# 9        0.295625      2.166005e-01     3.392455e-01         0.379575
# 10       0.272286      1.887903e-01     2.983550e-01         0.359975
# 11       0.361035      2.080132e+12     6.253831e+11         0.377622
# 12       0.392343      2.565594e-01     3.730387e-01         0.387786
# 13       0.350892      2.044906e-01     3.507098e-01         0.384748
# 14       0.371539      2.464083e-01     3.697078e-01         0.380318
# 15       0.364304      2.047375e-01     3.405219e-01         0.368548
# 16       0.336645      2.228074e-01     3.460257e-01         0.367632

# %%
plt.figure(figsize=(17,5))

plt.subplot(131)
plt.plot(epochs, history["loss"], label="Train loss")
plt.plot(epochs, history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(epochs, history["mrcnn_class_loss"], label="Train class ce")
plt.plot(epochs, history["val_mrcnn_class_loss"], label="Valid class ce")
plt.legend()
plt.subplot(133)
plt.plot(epochs, history["mrcnn_bbox_loss"], label="Train box loss")
plt.plot(epochs, history["val_mrcnn_bbox_loss"], label="Valid box loss")
plt.legend()

plt.show()

# %%
best_epoch = np.argmin(history["val_loss"])
print("Best Epoch:", best_epoch + 1, history["val_loss"][best_epoch])
# Out:
# Best Epoch: 16 1.4254010438919067

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[best_epoch])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model checkpoints/pneumonia20181106T1102/mask_rcnn_pneumonia_0016.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  checkpoints/pneumonia20181106T1102/mask_rcnn_pneumonia_0016.h5
# Re-starting from epoch 16

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps_1(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission
def predict(image_fps, filepath='submission.csv', min_conf=0.95):
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps):
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1)
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0:
                pass
            else:
                num_instances = len(r['rois'])

                for i in range(num_instances):
                    if r['scores'][i] > min_conf:
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1
                        height = r['rois'][i][2] - y1
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
submission_fp = os.path.join(ROOT_DIR, 'submission.csv')
predict(test_image_fps, filepath=submission_fp)
print(submission_fp)
# Out:
# 100%|██████████| 3000/3000 [03:08<00:00, 15.95it/s]
# checkpoints/submission.csv

# %%
# show a few test image detection example
def visualize(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

visualize()
visualize()
visualize()
visualize()
# Out:
# 2297bc72-aba0-4396-8d7c-dbc7cdca18ec
# [137 178 214 234]
# x 712 y 548 h 224 w 308
# [115  80 193 129]
# x 320 y 460 h 196 w 312
# 1d9a0d40-8406-4888-a727-7dd02e0b21aa
# [118  30 206  99]
# x 120 y 472 h 276 w 352
# 118ee78d-51a6-449e-9691-33f64f92e1e6
# [154  48 205 108]
# x 192 y 616 h 240 w 204
# [134 155 230 206]
# x 620 y 536 h 204 w 384
# 1bfdab1f-e19d-495c-aaaf-f64872a99c5a
# [107 156 184 221]
# x 624 y 428 h 260 w 308
# [124  33 178  97]
# x 132 y 496 h 256 w 216
